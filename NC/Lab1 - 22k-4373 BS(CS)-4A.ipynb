# %% [markdown]
# **Lab Task 1**: Plot all the given functions to observe the roots by visualization, fill the table by your visual guess of root. We have plotted one function for you.</br>
# 1) $f(x)=cos(x)-1.3x$</br>
# 2) $f(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 7.50]

def f(x):
    return (np.cos(x)-(1.3*x))

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 from matplotlib import pyplot as plt
#       4 plt.rcParams["figure.figsize"] = [7.50, 7.50]
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 7.50]

def f(x):
    return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 7.50]

def f(x):
    return ((2*x)*(np.cos(2*x))-((x+1)**2))

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %% [markdown]
# **Lab Task 2**: Complete the missing code of bisection method accordding to the explained algorithm and find root of given problems by bisection method according to the instructions given in table.</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.0001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''

def func(x):
    return (np.cos(x)-(1.3*x))

def bisection(func, x1, x2, tol=0.00001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            x2 = xr
        else:
            x1 = xr


        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

x1 = 1
x2 = 2
bisection(func, x1, x2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 from tabulate import tabulate
#       4 ## module Bisection
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.0001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''

def func(x):
    return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

def bisection(func, x1, x2, tol=0.00001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            x2 = xr
        else:
            x1 = xr


        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

x1 = 1
x2 = 1.5
bisection(func, x1, x2)
# Out:
# |   # |      x1 |       f(x1) |      x2 |        f(x2) |      xr |        f(xr) |       error |
# |-----|---------|-------------|---------|--------------|---------|--------------|-------------|
# |   2 | 1.25    | 0.019153    | 1.5     | -0.893894    | 1.25    |  0.019153    | 0.25        |
# |   3 | 1.25    | 0.019153    | 1.375   | -0.388747    | 1.375   | -0.388747    | 0.125       |
# |   4 | 1.25    | 0.019153    | 1.3125  | -0.172556    | 1.3125  | -0.172556    | 0.0625      |
# |   5 | 1.25    | 0.019153    | 1.28125 | -0.0736339   | 1.28125 | -0.0736339   | 0.03125     |
# |   6 | 1.25    | 0.019153    | 1.26562 | -0.0264729   | 1.26562 | -0.0264729   | 0.015625    |
# |   7 | 1.25    | 0.019153    | 1.25781 | -0.00346802  | 1.25781 | -0.00346802  | 0.0078125   |
# |   8 | 1.25391 | 0.00789046  | 1.25781 | -0.00346802  | 1.25391 |  0.00789046  | 0.00390625  |
# |   9 | 1.25586 | 0.00222322  | 1.25781 | -0.00346802  | 1.25586 |  0.00222322  | 0.00195312  |
# |  10 | 1.25586 | 0.00222322  | 1.25684 | -0.0006194   | 1.25684 | -0.0006194   | 0.000976562 |
# |  11 | 1.25635 | 0.00080266  | 1.25684 | -0.0006194   | 1.25635 |  0.00080266  | 0.000488281 |
# |  12 | 1.25659 | 9.18177e-05 | 1.25684 | -0.0006194   | 1.25659 |  9.18177e-05 | 0.000244141 |
# |  13 | 1.25659 | 9.18177e-05 | 1.25671 | -0.000263744 | 1.25671 | -0.000263744 | 0.00012207  |
# |  14 | 1.25659 | 9.18177e-05 | 1.25665 | -8.59515e-05 | 1.25665 | -8.59515e-05 | 6.10352e-05 |
# |  15 | 1.25662 | 2.93603e-06 | 1.25665 | -8.59515e-05 | 1.25662 |  2.93603e-06 | 3.05176e-05 |
# |  16 | 1.25662 | 2.93603e-06 | 1.25664 | -4.1507e-05  | 1.25664 | -4.1507e-05  | 1.52588e-05 |
# |  17 | 1.25662 | 2.93603e-06 | 1.25663 | -1.92853e-05 | 1.25663 | -1.92853e-05 | 7.62939e-06 |
#
# Root of given function is x=1.256629944 in n=16 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.0001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''

def func(x):
    return ((2*x)*(np.cos(2*x))-((x+1)**2))

def bisection(func, x1, x2, tol=0.00001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            x2 = xr
        else:
            x1 = xr


        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

x1 = -1
x2 = -0.5
bisection(func, x1, x2)
# Out:
# |   # |        x1 |       f(x1) |        x2 |        f(x2) |        xr |        f(xr) |       error |
# |-----|-----------|-------------|-----------|--------------|-----------|--------------|-------------|
# |   2 | -1        | 0.832294    | -0.75     | -0.168606    | -0.75     | -0.168606    | 0.25        |
# |   3 | -0.875    | 0.296306    | -0.75     | -0.168606    | -0.875    |  0.296306    | 0.125       |
# |   4 | -0.8125   | 0.0528816   | -0.75     | -0.168606    | -0.8125   |  0.0528816   | 0.0625      |
# |   5 | -0.8125   | 0.0528816   | -0.78125  | -0.0608144   | -0.78125  | -0.0608144   | 0.03125     |
# |   6 | -0.8125   | 0.0528816   | -0.796875 | -0.00468056  | -0.796875 | -0.00468056  | 0.015625    |
# |   7 | -0.804688 | 0.0239252   | -0.796875 | -0.00468056  | -0.804688 |  0.0239252   | 0.0078125   |
# |   8 | -0.800781 | 0.00957807  | -0.796875 | -0.00468056  | -0.800781 |  0.00957807  | 0.00390625  |
# |   9 | -0.798828 | 0.00243764  | -0.796875 | -0.00468056  | -0.798828 |  0.00243764  | 0.00195312  |
# |  10 | -0.798828 | 0.00243764  | -0.797852 | -0.00112424  | -0.797852 | -0.00112424  | 0.000976562 |
# |  11 | -0.79834  | 0.000656003 | -0.797852 | -0.00112424  | -0.79834  |  0.000656003 | 0.000488281 |
# |  12 | -0.79834  | 0.000656003 | -0.798096 | -0.000234294 | -0.798096 | -0.000234294 | 0.000244141 |
# |  13 | -0.798218 | 0.000210811 | -0.798096 | -0.000234294 | -0.798218 |  0.000210811 | 0.00012207  |
# |  14 | -0.798218 | 0.000210811 | -0.798157 | -1.17525e-05 | -0.798157 | -1.17525e-05 | 6.10352e-05 |
# |  15 | -0.798187 | 9.95265e-05 | -0.798157 | -1.17525e-05 | -0.798187 |  9.95265e-05 | 3.05176e-05 |
# |  16 | -0.798172 | 4.38863e-05 | -0.798157 | -1.17525e-05 | -0.798172 |  4.38863e-05 | 1.52588e-05 |
# |  17 | -0.798164 | 1.60667e-05 | -0.798157 | -1.17525e-05 | -0.798164 |  1.60667e-05 | 7.62939e-06 |
#
# Root of given function is x=-0.798164368 in n=16 number of iterations with a tolerence=0.0000

# %% [markdown]
# **Lab Task 3**: Find root of given problems by Newton Raphson method according to the instructions given in table.</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=1e-4, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
    return (np.cos(x)-(1.3*x))

def dfunc(x):
    return (-np.sin(x)-1.3)

def newton_raphson(func, dfunc, x0, tol=0.00001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
           raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")

x1 = 1.5
newton_raphson(func, dfunc, x1)
# Out:
# |   Iteration |       xr |        f(xr) |       error |
# |-------------|----------|--------------|-------------|
# |           1 | 0.682038 | -0.11036     | 0.817962    |
# |           2 | 0.624868 | -0.00128792  | 0.0571704   |
# |           3 | 0.624185 | -1.8934e-07  | 0.000683249 |
# |           4 | 0.624185 | -4.10783e-15 | 1.00476e-07 |
#
# Root of given function is x=0.624184578 in n=4 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=1e-4, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
    return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

def dfunc(x):
    return ((-x*np.sin(x))+np.cos(x)-(4*x)+3)

def newton_raphson(func, dfunc, x0, tol=0.00001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
           raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")

x1 = 1.5
newton_raphson(func, dfunc, x1)
# Out:
# |   Iteration |      xr |        f(xr) |      error |
# |-------------|---------|--------------|------------|
# |           1 | 1.29801 | -0.125935    | 0.201987   |
# |           2 | 1.25832 | -0.00494823  | 0.0396939  |
# |           3 | 1.25663 | -9.01156e-06 | 0.00169272 |
# |           4 | 1.25662 | -3.01079e-11 | 3.094e-06  |
#
# Root of given function is x=1.256623323 in n=4 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=1e-4, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
    return ((2*x)*(np.cos(2*x))-((x+1)**2))

def dfunc(x):
    return (((-4*x)*np.sin(2*x))+(2*np.cos(2*x))-(2*(x+1)))

def newton_raphson(func, dfunc, x0, tol=0.00001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
           raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")

x1 = -1.5
newton_raphson(func, dfunc, x1)
# Out:
# |   Iteration |         xr |           f(xr) |        error |
# |-------------|------------|-----------------|--------------|
# |           1 | -0.0109925 |    -1.00012     |  1.48901     |
# |           2 | 48.6918    | -2566.65        | 48.7028      |
# |           3 | 23.6571    |  -654.433       | 25.0346      |
# |           4 |  4.04892   |   -27.4468      | 19.6082      |
# |           5 |  3.00521   |   -10.2535      |  1.04371     |
# |           6 | -0.597681  |    -0.600171    |  3.60289     |
# |           7 | -0.859138  |     0.23265     |  0.261456    |
# |           8 | -0.800607  |     0.00894151  |  0.0585303   |
# |           9 | -0.798165  |     1.73404e-05 |  0.00244266  |
# |          10 | -0.79816   |     6.59733e-11 |  4.75555e-06 |
#
# Root of given function is x=-0.798159961 in n=10 number of iterations with a tolerence=0.0000

# %% [markdown]
# **Lab Task 4**: Find root of given problems by using fsolve command of sympy.optimize</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
from scipy.optimize import fsolve
import numpy as np

def f(x):

    return (np.cos(x)-(1.3*x))

print(fsolve(f, 1))
# Out:
# [0.62418458]

# %%
from scipy.optimize import fsolve
import numpy as np

def f(x):

    return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

print(fsolve(f, 0))
print(fsolve(f, 1))
# Out:
# [0.29753023]
# [1.25662332]

# %%
from scipy.optimize import fsolve
import numpy as np

def f(x):

    return ((2*x)*(np.cos(2*x))-((x+1)**2))

print(fsolve(f, -2))
print(fsolve(f, -1))
# Out:
# [-2.19130801]
# [-0.79815996]

# %% [markdown]
# **Lab Task 5**: Write program of Secant and False Position method by altering above codes.

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return (np.cos(x)-1.3*x)

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def secant(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xri = x1
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xri
        xr = formula(xri, xr1)
        xr1 = xrold
        xri = xr
        error=abs(xri-xrold)
        data.append([iter,xr1,xri,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','formula(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = 0
x1 = 1
secant(formula, x0, x1)
# Out:
# |   Iteration |       xr |   formula(xr) |       error |
# |-------------|----------|---------------|-------------|
# |           1 | 1        |      0.568279 | 0.431721    |
# |           2 | 0.568279 |      0.620293 | 0.0520131   |
# |           3 | 0.620293 |      0.624233 | 0.00394018  |
# |           4 | 0.624233 |      0.624185 | 4.81738e-05 |
# |           5 | 0.624185 |      0.624185 | 4.0404e-08  |
#
# Root of given function is x=0.624184578 in n=5 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def secant(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xri = x1
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xri
        xr = formula(xri, xr1)
        xr1 = xrold
        xri = xr
        error=abs(xri-xrold)
        data.append([iter,xr1,xri,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','formula(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = 1
x1 = 2
secant(formula, x0, x1)
# Out:
# |   Iteration |      xr |   formula(xr) |       error |
# |-------------|---------|---------------|-------------|
# |           1 | 2       |       1.12357 | 0.876434    |
# |           2 | 1.12357 |       1.1934  | 0.0698366   |
# |           3 | 1.1934  |       1.26817 | 0.0747644   |
# |           4 | 1.26817 |       1.25579 | 0.0123784   |
# |           5 | 1.25579 |       1.25661 | 0.000824845 |
# |           6 | 1.25661 |       1.25662 | 1.02988e-05 |
# |           7 | 1.25662 |       1.25662 | 9.28821e-09 |
#
# Root of given function is x=1.256623323 in n=7 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return ((2*x)*(np.cos(2*x))-((x+1)**2))

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def secant(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xri = x1
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xri
        xr = formula(xri, xr1)
        xr1 = xrold
        xri = xr
        error=abs(xri-xrold)
        data.append([iter,xr1,xri,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','formula(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = -1
x1 = 0
secant(formula, x0, x1)
# Out:
# |   Iteration |        xr |   formula(xr) |       error |
# |-------------|-----------|---------------|-------------|
# |           1 |  0        |     -0.545764 | 0.545764    |
# |           2 | -0.545764 |     -1.87978  | 1.33402     |
# |           3 | -1.87978  |     -0.861345 | 1.01844     |
# |           4 | -0.861345 |     -0.741329 | 0.120016    |
# |           5 | -0.741329 |     -0.795319 | 0.0539893   |
# |           6 | -0.795319 |     -0.798302 | 0.00298316  |
# |           7 | -0.798302 |     -0.79816  | 0.000142048 |
# |           8 | -0.79816  |     -0.79816  | 3.23504e-07 |
#
# Root of given function is x=-0.798159961 in n=8 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return (np.cos(x)-1.3*x)

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def false_position(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xr2 = x1
    xr = xr2
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xr
        xr = formula(xr2, xr1)
        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            xr2 = xr
        else:
            xr1 = xr
        error=abs(xr-xrold)
        y = func(xr)
        data.append([iter,xr1,xr2,xr,y,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr1','xr2','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = 0
x1 = 1
false_position(formula, x0, x1)
# Out:
# |   Iteration |      xr1 |      xr2 |       xr |        f(xr) |       error |
# |-------------|----------|----------|----------|--------------|-------------|
# |           1 | 0        | 0.568279 | 0.568279 |  0.104065    | 0.431721    |
# |           2 | 0.634286 | 0.568279 | 0.634286 | -0.0190776   | 0.066007    |
# |           3 | 0.634286 | 0.62406  | 0.62406  |  0.000233929 | 0.010226    |
# |           4 | 0.634286 | 0.624184 | 0.624184 |  5.06484e-07 | 0.000123872 |
# |           5 | 0.634286 | 0.624185 | 0.624185 |  1.09651e-09 | 2.6819e-07  |
#
# Root of given function is x=0.624184577 in n=5 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return ((x*np.cos(x))-(2*(x**2))+(3*x)-1)

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def false_position(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xr2 = x1
    xr = xr2
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xr
        xr = formula(xr2, xr1)
        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            xr2 = xr
        else:
            xr1 = xr
        error=abs(xr-xrold)
        y = func(xr)
        data.append([iter,xr1,xr2,xr,y,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr1','xr2','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = 1
x1 = 2
false_position(formula, x0, x1)
# Out:
# |   Iteration |     xr1 |     xr2 |      xr |        f(xr) |       error |
# |-------------|---------|---------|---------|--------------|-------------|
# |           1 | 1       | 1.12357 | 1.12357 |  0.331806    | 0.876434    |
# |           2 | 1.32021 | 1.12357 | 1.32021 | -0.197908    | 0.196646    |
# |           3 | 1.32021 | 1.24674 | 1.24674 |  0.0284731   | 0.0734693   |
# |           4 | 1.32021 | 1.25598 | 1.25598 |  0.00186496  | 0.00924062  |
# |           5 | 1.32021 | 1.25658 | 1.25658 |  0.000119862 | 0.0005996   |
# |           6 | 1.32021 | 1.25662 | 1.25662 |  7.69425e-06 | 3.85135e-05 |
# |           7 | 1.32021 | 1.25662 | 1.25662 |  4.93873e-07 | 2.47217e-06 |
#
# Root of given function is x=1.256623153 in n=7 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, 0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''
def func(x):
  return ((2*x)*(np.cos(2*x))-((x+1)**2))

def formula(xi, xold, f=func):
  return (xi - ((f(xi)*(xi-xold))/(f(xi)-f(xold))))

def false_position(formula, x0, x1, tol=0.00001, max_iter=1000):
    xr1 = x0
    xr2 = x1
    xr = xr2
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        xrold = xr
        xr = formula(xr2, xr1)
        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test < 0:
            xr2 = xr
        else:
            xr1 = xr
        error=abs(xr-xrold)
        y = func(xr)
        data.append([iter,xr1,xr2,xr,y,error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr1','xr2','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
x0 = -1
x1 = 0
false_position(formula, x0, x1)
# Out:
# |   Iteration |       xr1 |       xr2 |        xr |        f(xr) |       error |
# |-------------|-----------|-----------|-----------|--------------|-------------|
# |           1 | -0.545764 |  0        | -0.545764 | -0.709667    | 0.545764    |
# |           2 | -0.545764 | -1.87978  | -1.87978  |  2.29023     | 1.33402     |
# |           3 | -0.545764 | -0.861345 | -0.861345 |  0.241436    | 1.01844     |
# |           4 | -0.781235 | -0.861345 | -0.781235 | -0.0608663   | 0.0801097   |
# |           5 | -0.797365 | -0.861345 | -0.797365 | -0.00289732  | 0.0161295   |
# |           6 | -0.798124 | -0.861345 | -0.798124 | -0.000132762 | 0.000758681 |
# |           7 | -0.798158 | -0.861345 | -0.798158 | -6.07266e-06 | 3.47456e-05 |
# |           8 | -0.79816  | -0.861345 | -0.79816  | -2.77746e-07 | 1.58925e-06 |
#
# Root of given function is x=-0.798159885 in n=8 number of iterations with a tolerence=0.0000
