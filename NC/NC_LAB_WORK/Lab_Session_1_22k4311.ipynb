# %% [markdown]
# **Lab Task 1**: Plot all the given functions to observe the roots by visualization, fill the table by your visual guess of root. We have plotted one function for you.</br>
# 1) $f(x)=cos(x)-1.3x$</br>
# 2) $f(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 5.50]

def f(x):
    return (x**2-10*np.cos(x))

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 5.50]

def f(x):
    return (np.cos(x)-1.3*x)

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 5.50]

def f(x):
    return (x*np.cos(x)-2*x*x+3*x-1)

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 5.50]

def f(x):
    return (2*x*np.cos(2*x)-(x+1)*(x+1))

x = np.linspace(-10,10 , 1000)
plt.plot(x,f(x), color='red')
plt.hlines(y=0,xmin=-10,xmax=10,color='blue')
plt.show()

# %% [markdown]
# **Lab Task 2**: Complete the missing code of bisection method accordding to the explained algorithm and find root of given problems by bisection method according to the instructions given in table.</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.0001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''
def bisection(func, x1, x2, tol=0.001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1 #first error ignored

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test > 0:
          x1 = xr
        else :
          x2 = xr

        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

def func(x):
    return ((x*x*x)+(4*x)-10)
    #return np.cos(x)-1.3*x

root = bisection(func, -3, 4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numpy as np
#       2 from tabulate import tabulate
#       4 ## module Bisection
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.0001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''
def bisection(func, x1, x2, tol=0.00001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1 #first error ignored

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test > 0:
          x1 = xr
        else :
          x2 = xr

        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

def func(x):
    return (x*np.cos(x)-2*x*x+3*x-1)

root = bisection(func, 1, 3)
# Out:
# |   # |      x1 |       f(x1) |      x2 |        f(x2) |      xr |        f(xr) |       error |
# |-----|---------|-------------|---------|--------------|---------|--------------|-------------|
# |   2 | 1       | 0.540302    | 2       | -3.83229     | 2       | -3.83229     | 1           |
# |   3 | 1       | 0.540302    | 1.5     | -0.893894    | 1.5     | -0.893894    | 0.5         |
# |   4 | 1.25    | 0.019153    | 1.5     | -0.893894    | 1.25    |  0.019153    | 0.25        |
# |   5 | 1.25    | 0.019153    | 1.375   | -0.388747    | 1.375   | -0.388747    | 0.125       |
# |   6 | 1.25    | 0.019153    | 1.3125  | -0.172556    | 1.3125  | -0.172556    | 0.0625      |
# |   7 | 1.25    | 0.019153    | 1.28125 | -0.0736339   | 1.28125 | -0.0736339   | 0.03125     |
# |   8 | 1.25    | 0.019153    | 1.26562 | -0.0264729   | 1.26562 | -0.0264729   | 0.015625    |
# |   9 | 1.25    | 0.019153    | 1.25781 | -0.00346802  | 1.25781 | -0.00346802  | 0.0078125   |
# |  10 | 1.25391 | 0.00789046  | 1.25781 | -0.00346802  | 1.25391 |  0.00789046  | 0.00390625  |
# |  11 | 1.25586 | 0.00222322  | 1.25781 | -0.00346802  | 1.25586 |  0.00222322  | 0.00195312  |
# |  12 | 1.25586 | 0.00222322  | 1.25684 | -0.0006194   | 1.25684 | -0.0006194   | 0.000976562 |
# |  13 | 1.25635 | 0.00080266  | 1.25684 | -0.0006194   | 1.25635 |  0.00080266  | 0.000488281 |
# |  14 | 1.25659 | 9.18177e-05 | 1.25684 | -0.0006194   | 1.25659 |  9.18177e-05 | 0.000244141 |
# |  15 | 1.25659 | 9.18177e-05 | 1.25671 | -0.000263744 | 1.25671 | -0.000263744 | 0.00012207  |
# |  16 | 1.25659 | 9.18177e-05 | 1.25665 | -8.59515e-05 | 1.25665 | -8.59515e-05 | 6.10352e-05 |
# |  17 | 1.25662 | 2.93603e-06 | 1.25665 | -8.59515e-05 | 1.25662 |  2.93603e-06 | 3.05176e-05 |
# |  18 | 1.25662 | 2.93603e-06 | 1.25664 | -4.1507e-05  | 1.25664 | -4.1507e-05  | 1.52588e-05 |
# |  19 | 1.25662 | 2.93603e-06 | 1.25663 | -1.92853e-05 | 1.25663 | -1.92853e-05 | 7.62939e-06 |
#
# Root of given function is x=1.256629944 in n=18 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Bisection
''' root = bisection(func, x1, x2, tol=0.00001, max_iter=100):.
    Finds a root of f(x) = 0 by bisection.
    The root must be bracketed in (x1,x2).

'''
def bisection(func, x1, x2, tol=0.001, max_iter=100):
    if func(x1) * func(x2) >= 0:
        return  "Error: Choose different interval, function should have different signs at the interval endpoints."
    data=[]
    iter = 0
    xr = x2
    error = tol + 1 #first error ignored

    while iter < max_iter and error > tol:
        xrold = xr
        xr = ((x1+x2)/2)
        iter += 1
        error = abs((xr - xrold) )

        test = func(x1) * func(xr)
        # write your code here to replace value of x1 or x2 by xr
        if test > 0:
          x1 = xr
        else :
          x2 = xr

        data.append([iter+1,x1,func(x1),x2,func(x2),xr,func(xr),error])
    print(tabulate(data,headers=['#','x1','f(x1)','x2','f(x2)','xr','f(xr)',"error"],tablefmt="github"))
    print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))

    return

def func(x):
    return (2*x*np.cos(2*x)-(x+1)*(x+1))

root = bisection(func, -2, 1)
# Out:
# |   # |        x1 |      f(x1) |        x2 |        f(x2) |        xr |        f(xr) |       error |
# |-----|-----------|------------|-----------|--------------|-----------|--------------|-------------|
# |   2 | -2        | 1.61457    | -0.5      | -0.790302    | -0.5      | -0.790302    | 1.5         |
# |   3 | -1.25     | 1.94036    | -0.5      | -0.790302    | -1.25     |  1.94036     | 0.75        |
# |   4 | -0.875    | 0.296306   | -0.5      | -0.790302    | -0.875    |  0.296306    | 0.375       |
# |   5 | -0.875    | 0.296306   | -0.6875   | -0.365159    | -0.6875   | -0.365159    | 0.1875      |
# |   6 | -0.875    | 0.296306   | -0.78125  | -0.0608144   | -0.78125  | -0.0608144   | 0.09375     |
# |   7 | -0.828125 | 0.111819   | -0.78125  | -0.0608144   | -0.828125 |  0.111819    | 0.046875    |
# |   8 | -0.804688 | 0.0239252  | -0.78125  | -0.0608144   | -0.804688 |  0.0239252   | 0.0234375   |
# |   9 | -0.804688 | 0.0239252  | -0.792969 | -0.0188499   | -0.792969 | -0.0188499   | 0.0117188   |
# |  10 | -0.798828 | 0.00243764 | -0.792969 | -0.0188499   | -0.798828 |  0.00243764  | 0.00585938  |
# |  11 | -0.798828 | 0.00243764 | -0.795898 | -0.0082313   | -0.795898 | -0.0082313   | 0.00292969  |
# |  12 | -0.798828 | 0.00243764 | -0.797363 | -0.0029031   | -0.797363 | -0.0029031   | 0.00146484  |
# |  13 | -0.798828 | 0.00243764 | -0.798096 | -0.000234294 | -0.798096 | -0.000234294 | 0.000732422 |
#
# Root of given function is x=-0.798095703 in n=12 number of iterations with a tolerence=0.0010

# %% [markdown]
# **Lab Task 3**: Find root of given problems by Newton Raphson method according to the instructions given in table.</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=0.001, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''

def func(x):
    return np.cos(x)-1.3*x

def dfunc(x):
    return -np.sin(x)-1.3

def newton_raphson(func, dfunc, x0, tol=0.00001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
           raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
root = newton_raphson(func,dfunc,1)
# Out:
# |   Iteration |       xr |        f(xr) |       error |
# |-------------|----------|--------------|-------------|
# |           1 | 0.645245 | -0.0398659   | 0.354755    |
# |           2 | 0.624278 | -0.000176528 | 0.0209667   |
# |           3 | 0.624185 | -3.55988e-09 | 9.36729e-05 |
# |           4 | 0.624185 | -2.22045e-16 | 1.88909e-09 |
#
# Root of given function is x=0.624184578 in n=4 number of iterations with a tolerence=0.0000

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=1e-4, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''

def func(x):
    return (x*np.cos(x)-2*x*x+3*x-1)

def dfunc(x):
    return np.cos(x)-x*np.sin(x)-4*x+3

def newton_raphson(func, dfunc, x0, tol=0.001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
           raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
root = newton_raphson(func,dfunc,1)
# Out:
# |   Iteration |      xr |        f(xr) |       error |
# |-------------|---------|--------------|-------------|
# |           1 | 1.41524 | -0.540841    | 0.415244    |
# |           2 | 1.27672 | -0.0597912   | 0.138528    |
# |           3 | 1.25704 | -0.00121677  | 0.0196752   |
# |           4 | 1.25662 | -5.47933e-07 | 0.000417389 |
#
# Root of given function is x=1.256623511 in n=4 number of iterations with a tolerence=0.0010

# %%
import numpy as np
from tabulate import tabulate

## module Newton_Raphson
''' newton_raphson(func, dfunc, x0, tol=1e-4, max_iter=1000)
    Finds a root of f(x) = 0 by newton_raphson.
'''

def func(x):
    return 2*x*np.cos(2*x)-(x+1)*(x+1)

def dfunc(x):
    return 2*np.cos(2 * x)-4*x*np.sin(2 * x)-2*(x + 1)

def newton_raphson(func, dfunc, x0, tol=0.001, max_iter=1000):
    xr = x0
    data=[]
    iter = 0
    error = tol + 1
    for i in range(max_iter):
        iter+=1
        fx = func(xr)
        dx = dfunc(xr)
        if abs(dx) < tol:
          raise Exception("Derivative is close to zero!")
        xrold=xr
        xr = xr - fx/dx
        error=abs(xr-xrold)
        data.append([iter,xr,func(xr),error])
        if error < tol:
           print(tabulate(data,headers=['Iteration','xr','f(xr)',"error"],tablefmt="github"))
           print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerence=%.4f' %(xr,iter,tol))
           return

    raise Exception("Max iterations reached")
root = newton_raphson(func,dfunc,3)
# Out:
# |   Iteration |        xr |        f(xr) |       error |
# |-------------|-----------|--------------|-------------|
# |           1 | -0.755117 | -0.151374    | 3.75512     |
# |           2 | -0.799854 |  0.0061863   | 0.0447371   |
# |           3 | -0.798162 |  8.32996e-06 | 0.00169201  |
# |           4 | -0.79816  |  1.52242e-11 | 2.28447e-06 |
#
# Root of given function is x=-0.798159961 in n=4 number of iterations with a tolerence=0.0010

# %% [markdown]
# **Lab Task 4**: Find root of given problems by using fsolve command of sympy.optimize</br>
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return (np.cos(x)-1.3*x)

root = fsolve(f, 0)
print(root)
# Out:
# [0.62418458]

# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return (x*np.cos(x)-2*x*x+3*x-1)

root = fsolve(f,0)
print(root)
# Out:
# [0.29753023]

# %%
from scipy.optimize import fsolve
import numpy as np
def f(x):
    return (2*x*np.cos(2*x))-(x+1)*(x+1)

root = fsolve(f,1)
print(root)
# Out:
# [-0.79815996]

# %% [markdown]
# **Lab Task 5**: Write program of Secant and False Position method by altering above codes.

# %% [markdown]
# Secant
#
# 1) $f1(x)=cos(x)-1.3x$</br>
# 2) $f2(x)=xcos(x)-2x^2+3x-1$</br>
# 3) $f3(x)=2xcos(2x)-(x+1)^2$

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return np.cos(x) - 1.3 * x

def secant(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if fx1 - fx0 == 0:
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', "error"], tablefmt="github"))
            print('\nRoot of given function is x=%.9f and x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x0, x1, iter, tol))
            return
        x0, x1 = x1, x2
    raise Exception("Max iterations reached")

secant(func, 1, 0)
# Out:
# |   Iteration |       x0 |        f(x0) |       x1 |        f(x1) |       error |
# |-------------|----------|--------------|----------|--------------|-------------|
# |           1 | 1        | -0.759698    | 0        |  1           | 0.568279    |
# |           2 | 0        |  1           | 0.568279 |  0.104065    | 0.066007    |
# |           3 | 0.568279 |  0.104065    | 0.634286 | -0.0190776   | 0.010226    |
# |           4 | 0.634286 | -0.0190776   | 0.62406  |  0.000233929 | 0.000123872 |
# |           5 | 0.62406  |  0.000233929 | 0.624184 |  5.06484e-07 | 2.68779e-07 |
#
# Root of given function is x=0.624060437 and x=0.624184309 in n=5 number of iterations with a tolerance=0.0001

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return x*np.cos(x)-(2*x*x)+3*x-1

def secant(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if fx1 - fx0 == 0:
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', "error"], tablefmt="github"))
            print('\nRoot of given function is x=%.9f and x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x0, x1, iter, tol))
            return
        x0, x1 = x1, x2
    raise Exception("Max iterations reached")

secant(func, 1, 0)
# Out:
# |   Iteration |       x0 |        f(x0) |       x1 |        f(x1) |       error |
# |-------------|----------|--------------|----------|--------------|-------------|
# |           1 | 1        |  0.540302    | 0        | -1           | 0.649223    |
# |           2 | 0        | -1           | 0.649223 |  0.621829    | 0.24892     |
# |           3 | 0.649223 |  0.621829    | 0.400303 |  0.24908     | 0.166335    |
# |           4 | 0.400303 |  0.24908     | 0.233968 | -0.179984    | 0.0697742   |
# |           5 | 0.233968 | -0.179984    | 0.303742 |  0.0165466   | 0.00587452  |
# |           6 | 0.303742 |  0.0165466   | 0.297868 |  0.000904197 | 0.000339573 |
# |           7 | 0.297868 |  0.000904197 | 0.297528 | -5.1454e-06  | 1.92143e-06 |
#
# Root of given function is x=0.297867886 and x=0.297528313 in n=7 number of iterations with a tolerance=0.0001

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return 2*x*np.cos(2*x)-(x+1)*(x+1)

def secant(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if fx1 - fx0 == 0:
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', "error"], tablefmt="github"))
            print('\nRoot of given function is x=%.9f and x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x0, x1, iter, tol))
            return
        x0, x1 = x1, x2
    raise Exception("Max iterations reached")

secant(func, 2, 1)
# Out:
# |   Iteration |         x0 |        f(x0) |         x1 |        f(x1) |       error |
# |-------------|------------|--------------|------------|--------------|-------------|
# |           1 |  2         | -11.6146     |  1         | -4.83229     | 0.712488    |
# |           2 |  1         |  -4.83229    |  0.287512  | -1.17514     | 0.228941    |
# |           3 |  0.287512  |  -1.17514    |  0.0585711 | -1.00423     | 1.34525     |
# |           4 |  0.0585711 |  -1.00423    | -1.28668   |  2.08676     | 0.908189    |
# |           5 | -1.28668   |   2.08676    | -0.378486  | -0.936537    | 0.281333    |
# |           6 | -0.378486  |  -0.936537   | -0.659819  | -0.443688    | 0.253271    |
# |           7 | -0.659819  |  -0.443688   | -0.913089  |  0.453768    | 0.128058    |
# |           8 | -0.913089  |   0.453768   | -0.785032  | -0.0473617   | 0.0121027   |
# |           9 | -0.785032  |  -0.0473617  | -0.797135  | -0.00373598  | 0.00103644  |
# |          10 | -0.797135  |  -0.00373598 | -0.798171  |  4.01493e-05 | 1.10199e-05 |
#
# Root of given function is x=-0.797134530 and x=-0.798170972 in n=10 number of iterations with a tolerance=0.0001

# %% [markdown]
# False Position

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return np.cos(x) - 1.3 * x

def false(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if (fx0*fx1 >0):
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        fx2 = func(x2)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, x2, fx2, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', 'x2', 'f(x2)', 'error'], tablefmt="github"))
            print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x2, iter, tol))
            return
        if fx2 * fx1 > 0:
            x1 = x2
        else:
            x0 = x2
    raise Exception("Max iterations reached")

false(func, 1, -2)
# Out:
# |   Iteration |   x0 |     f(x0) |        x1 |       f(x1) |       x2 |       f(x2) |       error |
# |-------------|------|-----------|-----------|-------------|----------|-------------|-------------|
# |           1 |    1 | -0.759698 | -2        | 2.18385     | 0.225733 | 0.681177    | 2.22573     |
# |           2 |    1 | -0.759698 |  0.225733 | 0.681177    | 0.59177  | 0.0606541   | 0.366036    |
# |           3 |    1 | -0.759698 |  0.59177  | 0.0606541   | 0.621953 | 0.00420336  | 0.0301832   |
# |           4 |    1 | -0.759698 |  0.621953 | 0.00420336  | 0.624033 | 0.000285367 | 0.0020802   |
# |           5 |    1 | -0.759698 |  0.624033 | 0.000285367 | 0.624174 | 1.93462e-05 | 0.000141172 |
# |           6 |    1 | -0.759698 |  0.624174 | 1.93462e-05 | 0.624184 | 1.31143e-06 | 9.57039e-06 |
#
# Root of given function is x=0.624183882 in n=6 number of iterations with a tolerance=0.0001

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return x*np.cos(x)-2*x*x+3*x-1

def false(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if (fx0*fx1 >0):
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        fx2 = func(x2)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, x2, fx2, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', 'x2', 'f(x2)', 'error'], tablefmt="github"))
            print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x2, iter, tol))
            return
        if fx2 * fx1 > 0:
            x1 = x2
        else:
            x0 = x2
    raise Exception("Max iterations reached")

false(func, 1,2)
# Out:
# |   Iteration |      x0 |       f(x0) |      x1 |        f(x1) |      x2 |        f(x2) |    error |
# |-------------|---------|-------------|---------|--------------|---------|--------------|----------|
# |           1 | 1       | 0.540302    | 2       | -3.83229     | 1.12357 |  0.331806    | 0.876434 |
# |           2 | 1.12357 | 0.331806    | 2       | -3.83229     | 1.1934  |  0.171557    | 0.806598 |
# |           3 | 1.1934  | 0.171557    | 2       | -3.83229     | 1.22796 |  0.0808903   | 0.772037 |
# |           4 | 1.22796 | 0.0808903   | 2       | -3.83229     | 1.24392 |  0.0364856   | 0.756078 |
# |           5 | 1.24392 | 0.0364856   | 2       | -3.83229     | 1.25105 |  0.0161276   | 0.748947 |
# |           6 | 1.25105 | 0.0161276   | 2       | -3.83229     | 1.25419 |  0.00706514  | 0.745809 |
# |           7 | 1.25419 | 0.00706514  | 2       | -3.83229     | 1.25556 |  0.00308291  | 0.744436 |
# |           8 | 1.25556 | 0.00308291  | 2       | -3.83229     | 1.25616 |  0.00134293  | 0.743838 |
# |           9 | 1.25616 | 0.00134293  | 2       | -3.83229     | 1.25642 |  0.000584549 | 0.743577 |
# |          10 | 1.25642 | 0.000584549 | 2       | -3.83229     | 1.25654 |  0.000254359 | 0.743464 |
# |          11 | 1.25654 | 0.000254359 | 2       | -3.83229     | 1.25659 |  0.000110665 | 0.743415 |
# |          12 | 1.25659 | 0.000110665 | 2       | -3.83229     | 1.25661 |  4.81445e-05 | 0.743393 |
# |          13 | 1.25661 | 4.81445e-05 | 2       | -3.83229     | 1.25662 |  2.09446e-05 | 0.743384 |
# |          14 | 1.25662 | 2.09446e-05 | 2       | -3.83229     | 1.25662 |  9.11156e-06 | 0.74338  |
# |          15 | 1.25662 | 9.11156e-06 | 2       | -3.83229     | 1.25662 |  3.96379e-06 | 0.743378 |
# |          16 | 1.25662 | 3.96379e-06 | 2       | -3.83229     | 1.25662 |  1.72436e-06 | 0.743377 |
# |          17 | 1.25662 | 1.72436e-06 | 2       | -3.83229     | 1.25662 |  7.50143e-07 | 0.743377 |
# |          18 | 1.25662 | 7.50143e-07 | 2       | -3.83229     | 1.25662 |  3.26333e-07 | 0.743377 |
# |          19 | 1.25662 | 3.26333e-07 | 2       | -3.83229     | 1.25662 |  1.41963e-07 | 0.743377 |
# |          20 | 1.25662 | 1.41963e-07 | 2       | -3.83229     | 1.25662 |  6.1758e-08  | 0.743377 |
# |          21 | 1.25662 | 6.1758e-08  | 2       | -3.83229     | 1.25662 |  2.68664e-08 | 0.743377 |
# |          22 | 1.25662 | 2.68664e-08 | 2       | -3.83229     | 1.25662 |  1.16876e-08 | 0.743377 |
# |          23 | 1.25662 | 1.16876e-08 | 2       | -3.83229     | 1.25662 |  5.08442e-09 | 0.743377 |
# |          24 | 1.25662 | 5.08442e-09 | 2       | -3.83229     | 1.25662 |  2.21186e-09 | 0.743377 |
# |          25 | 1.25662 | 2.21186e-09 | 2       | -3.83229     | 1.25662 |  9.6222e-10  | 0.743377 |
# |          26 | 1.25662 | 9.6222e-10  | 2       | -3.83229     | 1.25662 |  4.18591e-10 | 0.743377 |
# |          27 | 1.25662 | 4.18591e-10 | 2       | -3.83229     | 1.25662 |  1.82098e-10 | 0.743377 |
# |          28 | 1.25662 | 1.82098e-10 | 2       | -3.83229     | 1.25662 |  7.92175e-11 | 0.743377 |
# |          29 | 1.25662 | 7.92175e-11 | 2       | -3.83229     | 1.25662 |  3.44613e-11 | 0.743377 |
# |          30 | 1.25662 | 3.44613e-11 | 2       | -3.83229     | 1.25662 |  1.49916e-11 | 0.743377 |
# |          31 | 1.25662 | 1.49916e-11 | 2       | -3.83229     | 1.25662 |  6.52189e-12 | 0.743377 |
# |          32 | 1.25662 | 6.52189e-12 | 2       | -3.83229     | 1.25662 |  2.83729e-12 | 0.743377 |
# |          33 | 1.25662 | 2.83729e-12 | 2       | -3.83229     | 1.25662 |  1.23457e-12 | 0.743377 |
# |          34 | 1.25662 | 1.23457e-12 | 2       | -3.83229     | 1.25662 |  5.37348e-13 | 0.743377 |
# |          35 | 1.25662 | 5.37348e-13 | 2       | -3.83229     | 1.25662 |  2.33147e-13 | 0.743377 |
# |          36 | 1.25662 | 2.33147e-13 | 2       | -3.83229     | 1.25662 |  1.01696e-13 | 0.743377 |
# |          37 | 1.25662 | 1.01696e-13 | 2       | -3.83229     | 1.25662 |  4.35207e-14 | 0.743377 |
# |          38 | 1.25662 | 4.35207e-14 | 2       | -3.83229     | 1.25662 |  1.95399e-14 | 0.743377 |
# |          39 | 1.25662 | 1.95399e-14 | 2       | -3.83229     | 1.25662 |  8.43769e-15 | 0.743377 |
# |          40 | 1.25662 | 8.43769e-15 | 2       | -3.83229     | 1.25662 |  3.10862e-15 | 0.743377 |
# |          41 | 1.25662 | 3.10862e-15 | 2       | -3.83229     | 1.25662 |  1.77636e-15 | 0.743377 |
# |          42 | 1.25662 | 1.77636e-15 | 2       | -3.83229     | 1.25662 |  8.88178e-16 | 0.743377 |
# |          43 | 1.25662 | 8.88178e-16 | 2       | -3.83229     | 1.25662 | -4.44089e-16 | 0.743377 |
# |          44 | 1.25662 | 8.88178e-16 | 1.25662 | -4.44089e-16 | 1.25662 | -4.44089e-16 | 0        |
#
# Root of given function is x=1.256623323 in n=44 number of iterations with a tolerance=0.0001

# %%
import numpy as np
from tabulate import tabulate

def func(x):
    return 2*x*np.cos(2*x)-(x+1)*(x+1)

def false(func, x0, x1, tol=1e-4, max_iter=1000):
    data = []
    for iter in range(1, max_iter + 1):
        fx0 = func(x0)
        fx1 = func(x1)
        if (fx0*fx1 >0):
            print("Invalid intervals...")
            exit(1)
        x2 = x1 - (fx1 * (x1 - x0)) / (fx1 - fx0)
        fx2 = func(x2)
        error = abs(x2 - x1)
        data.append([iter, x0, fx0, x1, fx1, x2, fx2, error])
        if error < tol:
            print(tabulate(data, headers=['Iteration', 'x0', 'f(x0)', 'x1', 'f(x1)', 'x2', 'f(x2)', 'error'], tablefmt="github"))
            print('\nRoot of given function is x=%.9f in n=%d number of iterations with a tolerance=%.4f' % (x2, iter, tol))
            return
        if fx2 * fx1 > 0:
            x1 = x2
        else:
            x0 = x2
    raise Exception("Max iterations reached")

false(func, 1, -2)
# Out:
# |   Iteration |        x0 |        f(x0) |       x1 |       f(x1) |        x2 |        f(x2) |    error |
# |-------------|-----------|--------------|----------|-------------|-----------|--------------|----------|
# |           1 |  1        | -4.83229     | -2       | 1.61457     | -1.24867  |  1.93491     | 0.75133  |
# |           2 |  1        | -4.83229     | -1.24867 | 1.93491     | -0.60572  | -0.581485    | 0.64295  |
# |           3 | -0.60572  | -0.581485    | -1.24867 | 1.93491     | -0.754292 | -0.154163    | 0.494378 |
# |           4 | -0.754292 | -0.154163    | -1.24867 | 1.93491     | -0.790775 | -0.026768    | 0.457895 |
# |           5 | -0.790775 | -0.026768    | -1.24867 | 1.93491     | -0.797023 | -0.0041413   | 0.451647 |
# |           6 | -0.797023 | -0.0041413   | -1.24867 | 1.93491     | -0.797988 | -0.000627749 | 0.450683 |
# |           7 | -0.797988 | -0.000627749 | -1.24867 | 1.93491     | -0.798134 | -9.48544e-05 | 0.450536 |
# |           8 | -0.798134 | -9.48544e-05 | -1.24867 | 1.93491     | -0.798156 | -1.43259e-05 | 0.450514 |
# |           9 | -0.798156 | -1.43259e-05 | -1.24867 | 1.93491     | -0.798159 | -2.16347e-06 | 0.450511 |
# |          10 | -0.798159 | -2.16347e-06 | -1.24867 | 1.93491     | -0.79816  | -3.26722e-07 | 0.45051  |
# |          11 | -0.79816  | -3.26722e-07 | -1.24867 | 1.93491     | -0.79816  | -4.93406e-08 | 0.45051  |
# |          12 | -0.79816  | -4.93406e-08 | -1.24867 | 1.93491     | -0.79816  | -7.45126e-09 | 0.45051  |
# |          13 | -0.79816  | -7.45126e-09 | -1.24867 | 1.93491     | -0.79816  | -1.12527e-09 | 0.45051  |
# |          14 | -0.79816  | -1.12527e-09 | -1.24867 | 1.93491     | -0.79816  | -1.69934e-10 | 0.45051  |
# |          15 | -0.79816  | -1.69934e-10 | -1.24867 | 1.93491     | -0.79816  | -2.56629e-11 | 0.45051  |
# |          16 | -0.79816  | -2.56629e-11 | -1.24867 | 1.93491     | -0.79816  | -3.87573e-12 | 0.45051  |
# |          17 | -0.79816  | -3.87573e-12 | -1.24867 | 1.93491     | -0.79816  | -5.85323e-13 | 0.45051  |
# |          18 | -0.79816  | -5.85323e-13 | -1.24867 | 1.93491     | -0.79816  | -8.82003e-14 | 0.45051  |
# |          19 | -0.79816  | -8.82003e-14 | -1.24867 | 1.93491     | -0.79816  | -1.33019e-14 | 0.45051  |
# |          20 | -0.79816  | -1.33019e-14 | -1.24867 | 1.93491     | -0.79816  | -1.97065e-15 | 0.45051  |
# |          21 | -0.79816  | -1.97065e-15 | -1.24867 | 1.93491     | -0.79816  |  4.85723e-17 | 0.45051  |
# |          22 | -0.79816  | -1.97065e-15 | -0.79816 | 4.85723e-17 | -0.79816  |  4.85723e-17 | 0        |
#
# Root of given function is x=-0.798159961 in n=22 number of iterations with a tolerance=0.0001
